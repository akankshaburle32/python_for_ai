# %% [markdown]
# ### que 1.

# %%
a = 10
b = 20

sum = a + b
print("Sum =", sum)
# Out:
# Sum = 30

# %% [markdown]
# ### que 2.

# %%
num = 7

if num % 2 == 0:
    print("Even")
else:
    print("Odd")
# Out:
# Odd

# %% [markdown]
# ### que 3.

# %%
a = 10
b = 25
c = 15

largest = max(a, b, c)
print("Largest number:", largest)
# Out:
# Largest number: 25

# %% [markdown]
# ### que 4.

# %%
numbers = [1, 2, 3, 4, 5]

squares = [x * x for x in numbers]

print(squares)
# Out:
# [1, 4, 9, 16, 25]

# %% [markdown]
# ### que 5.

# %%
student = {
    "name": "Akanksha",
    "age": 22
}

for key, value in student.items():
    print(key, ":", value)
# Out:
# name : Akanksha
# age : 22

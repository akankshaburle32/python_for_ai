# %% [markdown]
# ### que 1.

# %%
a = 10
b = 20

sum = a + b
print("Sum =", sum)

# %% [markdown]
# ### que 2.

# %%
num = 7

if num % 2 == 0:
    print("Even")
else:
    print("Odd")

# %% [markdown]
# ### que 3.

# %%
a = 10
b = 25
c = 15

largest = max(a, b, c)
print("Largest number:", largest)

# %% [markdown]
# ### que 4.

# %%
numbers = [1, 2, 3, 4, 5]

squares = [x * x for x in numbers]

print(squares)

# %% [markdown]
# ### que 5.

# %%
x = 10
y = 5
print(x + y)

# %% [markdown]
# ### que 6.

# %%
a = 7
a = a + 3
print(a)

# %% [markdown]
# ### que 7.

# %%
num = 8
if num > 5:
    print("Big")
else:
    print("Small")

# %% [markdown]
# ### que 8.

# %%
for i in range(5):
    print(i)

# %% [markdown]
# ### que 9.

# %%
s = 0
for i in range(1, 6):
    s = s + i
print(s)

# %% [markdown]
# ### que 10.

# %%
for i in range(2, 10, 2):
    print(i)

# %%
s = 0
for i in range(1, 6):
    if i % 2 == 0:
        s = s + i
        print(s)
